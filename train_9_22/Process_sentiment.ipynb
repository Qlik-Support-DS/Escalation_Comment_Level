# %%
import pandas as pd
import numpy as np
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/gdrive')

# %cd /gdrive/MyDrive/qlik/escalation_project/train_9_27
# Out:
# Mounted at /gdrive

# %%
# Out:
# /gdrive/MyDrive/qlik/escalation_project/train_9_27

# %%
train_df = pd.read_csv("train_sentiment.csv")
train_df.shape
# Out:
# (152846, 35)

# %%
train_df.head()
# Out:
#    Unnamed: 0                  ID           PARENT_ID             CREATED_AT  \
# 0           0  00a3z00000wyB9cAAE  5003z00002eqG3kAAE  3/13/2023 11:21:07 AM
# 1           1  00a3z00000wwIEzAAM  5003z00002dVAvjAAG   1/26/2023 8:46:28 PM
# 2           2  00a3z00000wy5XsAAI  5003z00002fPQQYAA4   3/10/2023 1:22:27 AM
# 3           3  00a3z00000wwk1jAAA  5003z00002e9MYnAAM    2/7/2023 7:43:39 AM
# 4           4  00a3z00000wwBGeAAM  5003z00002cxyz4AAA   1/24/2023 3:51:51 PM
#
#   CREATED_DATE                                       COMMENT_BODY  \
# 0    3/13/2023  Community Author: KranthiKiranKundi\nAuthor em...
# 1    1/26/2023  Hello Saulo,\r\n\r\nGreetings for the day!\r\n...
# 2    3/10/2023  Qlik サポートにお問い合わせいただき、ありがとうございます。\r\n誠に恐れ入りますが、...
# 3     2/7/2023  Hello,\r\n\r\nIn order to assist you further, ...
# 4    1/24/2023  Hi Naresh\r\n\r\nSo we basically moved the pro...
#
#    IS_PUBLISHED  CUSTOMER_COMMENT_BOO  N_COMMENT  N_CUSTOMER_COMMENT  ...  \
# 0             1                     1          4                   2  ...
# 1             1                     0          8                   3  ...
# 2             1                     0          2                   1  ...
# 3             1                     0          3                   1  ...
# 4             1                     0         14                   9  ...
#
#    SEVERITY_AVG_UP_TO_COMMENT SEVERITY_COUNT_UP_TO_COMMENT  \
# 0                         NaN                            0
# 1                         NaN                            0
# 2                         NaN                            0
# 3                         NaN                            0
# 4                         NaN                            0
#
#    SEVERITY_LATEST_UP_TO_COMMENT  PRIORITY_MAX_UP_TO_COMMENT  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#    PRIORITY_AVG_UP_TO_COMMENT  PRIORITY_COUNT_UP_TO_COMMENT  \
# 0                         NaN                             0
# 1                         NaN                             0
# 2                         NaN                             0
# 3                         NaN                             0
# 4                         NaN                             0
#
#    PRIORITY_LATEST_UP_TO_COMMENT  sentiment_label sentiment_confidence_score  \
# 0                            NaN          neutral                   0.752239
# 1                            NaN         positive                   0.668101
# 2                            NaN          neutral                   0.845294
# 3                            NaN          neutral                   0.811268
# 4                            NaN          neutral                   0.861066
#
#   sentiment_score
# 0        0.584080
# 1        0.889367
# 2        0.615098
# 3        0.603756
# 4        0.620355
#
# [5 rows x 35 columns]
